# %% [markdown]
# <a href="https://colab.research.google.com/github/maro000/for_data_analysis_and_visualization/blob/master/Visualize_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.random import randn
import seaborn as sns

# Webブラウザに画像を埋め込むため
# %matplotlib inline

# %%
dataset = randn(100)
# カーネル密度推定とヒストグラムを描きます
sns.distplot(dataset,bins=25)

# %%
sns.distplot(dataset,rug=True,hist=False)

# %%
sns.distplot(dataset,bins=25,
             kde_kws={'color':'indianred','label': 'KED PLOT'},
             hist_kws={'color':'blue','label':"HISTOGRAM"})

# %%
from pandas import Series

# %%
ser1 = Series(dataset,name= 'My_data')

# %%
sns.distplot(ser1)
